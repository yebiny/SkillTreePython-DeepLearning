# %% [markdown]
# <a href="https://colab.research.google.com/github/yebiny/SkillTreePython-DeepLearning/blob/main/03.NLP-with-tensorflow2.0/%ED%95%B4%EC%84%A4/ch03_03_NLP%EA%B8%B0%EC%B4%88_%EC%88%9C%ED%99%98%EC%8B%A0%EA%B2%BD%EB%A7%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ch03.03 NLP기초 - 순환 신경망
# ---
#
# * 날짜:
# * 이름:
#
#
# ## 학습내용
#     - 순환 신경망에 대해 이해한다.
#     - RNN
#     - GRU
#     - LSTM

# %% [markdown]
# ```
# ! git clone https://github.com/yebiny/SkillTreePython-DeepLearning
# ```

# %%
! git clone https://github.com/yebiny/SkillTreePython-DeepLearning
# Out:
# Cloning into 'SkillTreePython-DeepLearning'...
# remote: Enumerating objects: 714, done.
# remote: Counting objects: 100% (287/287), done.
# remote: Compressing objects: 100% (131/131), done.
# remote: Total 714 (delta 176), reused 255 (delta 155), pack-reused 427
# Receiving objects: 100% (714/714), 38.09 MiB | 20.49 MiB/s, done.
# Resolving deltas: 100% (369/369), done.

# %% [markdown]
# ```
# import sys
# sys.path.append('/content/SkillTreePython-DeepLearning/scripts')
# from import_lib import *
# from plot_result import *
# ```

# %%
import sys
sys.path.append('/content/SkillTreePython-DeepLearning/scripts')
from import_lib import *
from plot_result import *

# %% [markdown]
# ## imdb 베이스 모델
# ---

# %% [markdown]
# ### **| imdb 데이터 처리**
# ```
# MAX_LEN = 256
# MAX_FEATURES = 10000
#
# imdb = tf.keras.datasets.imdb
# (x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=MAX_FEATURES)
# x_train = preprocessing.sequence.pad_sequences(x_train,
#                                                padding='post',
#                                                maxlen=MAX_LEN)
#
# x_test = preprocessing.sequence.pad_sequences(x_test,
#                                               padding='post',
#                                               maxlen=MAX_LEN)
# print(x_train.shape, x_test.shape)
# ```

# %%
MAX_LEN = 256
MAX_FEATURES = 10000

imdb = tf.keras.datasets.imdb
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=MAX_FEATURES)
x_train = preprocessing.sequence.pad_sequences(x_train,
                                               padding='post',
                                               maxlen=MAX_LEN)

x_test = preprocessing.sequence.pad_sequences(x_test,
                                              padding='post',
                                              maxlen=MAX_LEN)
print(x_train.shape, x_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 0s 0us/step
# 17473536/17464789 [==============================] - 0s 0us/step
# (25000, 256) (25000, 256)

# %% [markdown]
# ### **| FCN with GlobalAveragePooling1D**

# %%
EMB_DIMS = 32
x = layers.Input(shape=MAX_LEN)
y = layers.Embedding(MAX_FEATURES,EMB_DIMS)(x)
y = layers.GlobalAveragePooling1D()(y)
y = layers.Dense(1, activation='sigmoid')(y)
model = models.Model(x, y, name='FCNwithGAP')
model.summary()

model.compile(optimizer='rmsprop',
              loss = 'binary_crossentropy', 
              metrics = ['acc'])
history = model.fit(x_train, y_train,
                    epochs=20,
                    batch_size=128,
                    validation_split=0.2)
plot_lcurve([history], [''], ['dodgerblue'])
# Out:
# Model: "FCNwithGAP"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 256)]             0
#
#  embedding_7 (Embedding)     (None, 256, 32)           320000
#
#  global_average_pooling1d_5   (None, 32)               0
#  (GlobalAveragePooling1D)
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 320,033
# Trainable params: 320,033
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 157/157 [==============================] - 4s 4ms/step - loss: 0.6813 - acc: 0.6937 - val_loss: 0.6648 - val_acc: 0.7758
# Epoch 2/20
# 157/157 [==============================] - 1s 4ms/step - loss: 0.6445 - acc: 0.7735 - val_loss: 0.6208 - val_acc: 0.7820
# Epoch 3/20
# 157/157 [==============================] - 1s 3ms/step - loss: 0.5957 - acc: 0.7943 - val_loss: 0.5706 - val_acc: 0.7978
# Epoch 4/20
# 157/157 [==============================] - 1s 3ms/step - loss: 0.5435 - acc: 0.8175 - val_loss: 0.5210 - val_acc: 0.8132
# Epoch 5/20
# 157/157 [==============================] - 1s 3ms/step - loss: 0.4923 - acc: 0.8365 - val_loss: 0.4756 - val_acc: 0.8330
# Epoch 6/20
# 157/157 [==============================] - 1s 3ms/step - loss: 0.4453 - acc: 0.8523 - val_loss: 0.4361 - val_acc: 0.8456
# Epoch 7/20
# 157/157 [==============================] - 1s 3ms/step - loss: 0.4046 - acc: 0.8665 - val_loss: 0.4036 - val_acc: 0.8530
# Epoch 8/20
# 157/157 [==============================] - 1s 3ms/step - loss: 0.3706 - acc: 0.8739 - val_loss: 0.3771 - val_acc: 0.8628
# Epoch 9/20
# 157/157 [==============================] - 1s 3ms/step - loss: 0.3424 - acc: 0.8811 - val_loss: 0.3563 - val_acc: 0.8656
# Epoch 10/20
# 157/157 [==============================] - 1s 3ms/step - loss: 0.3189 - acc: 0.8871 - val_loss: 0.3400 - val_acc: 0.8704
# Epoch 11/20
# 157/157 [==============================] - 1s 3ms/step - loss: 0.2991 - acc: 0.8928 - val_loss: 0.3279 - val_acc: 0.8722
# Epoch 12/20
# 157/157 [==============================] - 1s 3ms/step - loss: 0.2825 - acc: 0.8982 - val_loss: 0.3155 - val_acc: 0.8752
# Epoch 13/20
# 157/157 [==============================] - 1s 3ms/step - loss: 0.2681 - acc: 0.9018 - val_loss: 0.3067 - val_acc: 0.8780
# Epoch 14/20
# 157/157 [==============================] - 1s 3ms/step - loss: 0.2557 - acc: 0.9059 - val_loss: 0.2998 - val_acc: 0.8810
# Epoch 15/20
# 157/157 [==============================] - 1s 3ms/step - loss: 0.2446 - acc: 0.9100 - val_loss: 0.2949 - val_acc: 0.8832
# Epoch 16/20
# 157/157 [==============================] - 1s 3ms/step - loss: 0.2348 - acc: 0.9139 - val_loss: 0.2901 - val_acc: 0.8818
# Epoch 17/20
# 157/157 [==============================] - 1s 3ms/step - loss: 0.2260 - acc: 0.9157 - val_loss: 0.2865 - val_acc: 0.8850
# Epoch 18/20
# 157/157 [==============================] - 1s 3ms/step - loss: 0.2180 - acc: 0.9194 - val_loss: 0.2836 - val_acc: 0.8864
# Epoch 19/20
# 157/157 [==============================] - 1s 3ms/step - loss: 0.2108 - acc: 0.9212 - val_loss: 0.2818 - val_acc: 0.8886
# Epoch 20/20
# 157/157 [==============================] - 1s 3ms/step - loss: 0.2041 - acc: 0.9247 - val_loss: 0.2806 - val_acc: 0.8866

# %% [markdown]
# ## RNN
# ---

# %% [markdown]
# <p align='center'>
# <img src=https://res.cloudinary.com/dyd911kmh/image/upload/v1647442110/image6_f6vds6.png width=800>
# </p>

# %%
EMB_DIMS = 32
x = layers.Input(shape=MAX_LEN)
y = layers.Embedding(MAX_FEATURES,EMB_DIMS)(x)
y = layers.SimpleRNN(32)(y)
y = layers.Dense(1, activation='sigmoid')(y)
model = models.Model(x, y, name='RNN')
model.summary()

model.compile(optimizer='rmsprop',
              loss = 'binary_crossentropy', 
              metrics = ['acc'])
history = model.fit(x_train, y_train,
                    epochs=5,
                    batch_size=128,
                    validation_split=0.2)
plot_lcurve([history], [''], ['dodgerblue'])
# Out:
# Model: "RNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 256)]             0
#
#  embedding_9 (Embedding)     (None, 256, 32)           320000
#
#  simple_rnn_1 (SimpleRNN)    (None, 32)                2080
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 322,113
# Trainable params: 322,113
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 157/157 [==============================] - 27s 164ms/step - loss: 0.6915 - acc: 0.5149 - val_loss: 0.6824 - val_acc: 0.5498
# Epoch 2/5
# 157/157 [==============================] - 26s 163ms/step - loss: 0.6371 - acc: 0.6393 - val_loss: 0.5777 - val_acc: 0.7220
# Epoch 3/5
# 157/157 [==============================] - 26s 164ms/step - loss: 0.6103 - acc: 0.6701 - val_loss: 0.6090 - val_acc: 0.6782
# Epoch 4/5
# 157/157 [==============================] - 26s 163ms/step - loss: 0.4762 - acc: 0.7979 - val_loss: 0.5630 - val_acc: 0.7560
# Epoch 5/5
# 157/157 [==============================] - 26s 163ms/step - loss: 0.4329 - acc: 0.8228 - val_loss: 0.5563 - val_acc: 0.7428

# %% [markdown]
# ## LSTM
# ---
#
# <p align='center'>
# <img src=https://res.cloudinary.com/dyd911kmh/image/upload/v1647442110/image3_nsnxp3.png width=600>
# </p>

# %%
EMB_DIMS = 32
x = layers.Input(shape=MAX_LEN)
y = layers.Embedding(MAX_FEATURES,EMB_DIMS)(x)
y = layers.LSTM(32)(y)
y = layers.Dense(1, activation='sigmoid')(y)
model = models.Model(x, y, name='LSTM')
model.summary()

model.compile(optimizer='rmsprop',
              loss = 'binary_crossentropy', 
              metrics = ['acc'])
history = model.fit(x_train, y_train,
                    epochs=20,
                    batch_size=128,
                    validation_split=0.2)
plot_lcurve([history], [''], ['dodgerblue'])
# Out:
# Model: "LSTM"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_13 (InputLayer)       [(None, 256)]             0
#
#  embedding_12 (Embedding)    (None, 256, 32)           320000
#
#  lstm_2 (LSTM)               (None, 32)                8320
#
#  dense_6 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 328,353
# Trainable params: 328,353
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 157/157 [==============================] - 6s 16ms/step - loss: 0.6483 - acc: 0.6058 - val_loss: 0.5354 - val_acc: 0.7664
# Epoch 2/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.4321 - acc: 0.8321 - val_loss: 0.7893 - val_acc: 0.6484
# Epoch 3/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.3480 - acc: 0.8756 - val_loss: 0.3407 - val_acc: 0.8752
# Epoch 4/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.3029 - acc: 0.8955 - val_loss: 1.0004 - val_acc: 0.6080
# Epoch 5/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.2674 - acc: 0.9079 - val_loss: 0.3294 - val_acc: 0.8554
# Epoch 6/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.2343 - acc: 0.9197 - val_loss: 0.4028 - val_acc: 0.8082
# Epoch 7/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.2141 - acc: 0.9277 - val_loss: 0.3151 - val_acc: 0.8792
# Epoch 8/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.2027 - acc: 0.9307 - val_loss: 0.4257 - val_acc: 0.8394
# Epoch 9/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.1807 - acc: 0.9451 - val_loss: 0.5072 - val_acc: 0.8612
# Epoch 10/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.1733 - acc: 0.9485 - val_loss: 0.5659 - val_acc: 0.8408
# Epoch 11/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.1622 - acc: 0.9518 - val_loss: 0.3515 - val_acc: 0.8818
# Epoch 12/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.1521 - acc: 0.9551 - val_loss: 0.3910 - val_acc: 0.8774
# Epoch 13/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.1521 - acc: 0.9568 - val_loss: 0.5258 - val_acc: 0.8300
# Epoch 14/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.1342 - acc: 0.9625 - val_loss: 0.3888 - val_acc: 0.8748
# Epoch 15/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.1365 - acc: 0.9603 - val_loss: 0.3805 - val_acc: 0.8754
# Epoch 16/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.1333 - acc: 0.9628 - val_loss: 0.3616 - val_acc: 0.8706
# Epoch 17/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.1378 - acc: 0.9591 - val_loss: 0.3710 - val_acc: 0.8788
# Epoch 18/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.1384 - acc: 0.9600 - val_loss: 0.3973 - val_acc: 0.8790
# Epoch 19/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.1310 - acc: 0.9644 - val_loss: 0.4060 - val_acc: 0.8764
# Epoch 20/20
# 157/157 [==============================] - 2s 13ms/step - loss: 0.1307 - acc: 0.9627 - val_loss: 0.3974 - val_acc: 0.8594

# %% [markdown]
# ### | **many-to-many**
#
#
# <p align='center'>
# <img src=https://res.cloudinary.com/dyd911kmh/image/upload/v1647442111/image9_e1gwba.png width=700>
# </p>

# %% [markdown]
# ## GRU
# ---
#
#
# <p align='center'>
# <img src=https://res.cloudinary.com/dyd911kmh/image/upload/v1647442111/image10_zgefie.png width=600>
# </p>

# %% [markdown]
# ### | **many-to-many**
#
#
# <p align='center'>
# <img src=https://res.cloudinary.com/dyd911kmh/image/upload/v1647442111/image9_e1gwba.png width=700>
# </p>
